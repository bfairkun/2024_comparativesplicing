# %%
import pandas as pd

# %%
dat = pd.read_csv("../code/config/STAR_Genome_List.tsv", sep='\t')

# %%
dat
# Out:
#                                   GenomeName  \
# 0                           Human_ensemblv75
# 1                         Chicken_ensemblv84
# 2                         Macaque_ensemblv84
# 3                         Opossum_ensemblv84
# 4                           Mouse_ensemblv84
# 5                         Rabbit_ensemblv_84
# 6                            Rat_ensemblv_79
# 7                       Lamprey_ensemblv_112
# 8             SalpingoecaRosetta_ensemblv_59
# 9   StarletSeaAnemone_RefSeq_GCF_932526225.1
# 10                        Human_ensembl_v112
# 11                      Chicken_ensembl_v112
# 12                      Macaque_ensembl_v112
# 13                      Opossum_ensembl_v112
# 14                        Mouse_ensembl_v112
# 15                       Rabbit_ensembl_v112
# 16                          Rat_ensembl_v112
# 17              Chicken_UCSC.galGal6_ensv101
# 18             Macaque_UCSC.rheMac10_ensv101
# 19          Opossum_UCSC.monDom5_ensvUnknown
# ...
